# %% [markdown]
# <a href="https://colab.research.google.com/github/richardcsuwandi/ppsdcw2/blob/main/demo_cw2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Analysis with Python
#
# By: [Richard Cornelius Suwandi](https://richardcsuwandi.github.io/)
#
# <img src="https://www.digitalvidya.com/wp-content/uploads/2018/01/Image.jpg" width="400" height="250" />

# %% [markdown]
# ## Apa itu Data Analysis?
# > A process of inspecting, cleansing, transforming, and modeling data with the goal of **discovering useful information, informing conclusion, and supporting decision-making**. ([Wikipedia)](https://en.wikipedia.org/wiki/Data_analysis)
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/ba/Data_visualization_process_v1.png/525px-Data_visualization_process_v1.png" width=400 height=300/>

# %% [markdown]
# ## Mengapa Python?
# Berikut adalah 3 alasan mengapa Python cocok untuk data analysis:
# 1. Python adalah salah satu bahasa pemrograman yang relatif **mudah untuk dipelajari**
# 2. Python dilengkapi dengan **banyak libraries dan tools** yang memudahkan proses data analysis
# 3. Python didukung oleh **komunitas yang besar dan aktif**

# %% [markdown]
# ## Libraries dan Tools untuk Data Analysis
# Python memiliki banyak libraries dan tools yang dapat digunakan dalam proses data analysis, antara lainnya yaitu:
# - **NumPy & SciPy**: Numerical computing
# - **Pandas**: Data manipulation
# - **Matplotlib & Seaborn**: Data visualization
# - **Scikit-learn**: Machine learning
#
# <img src="https://i2.wp.com/makemeanalyst.com/wp-content/uploads/2017/09/Python-libraries-for-data-analysis.png?zoom=1.5&resize=602%2C253" width=500 height=200/>

# %% [markdown]
# ## Studi Kasus
# Pada workshop kali ini, kita akan menganalisa data *'Bike Sales'* yaitu data penjualan dari sebuah toko sepeda. Dataset yang akan kita gunakan dapat didownload melalui link [ini](https://github.com/richardcsuwandi/ppsdcw2/blob/main/bike_sales.csv)
#
# <img src="https://www.flokq.com/blog/wp-content/uploads/2020/07/bicycle.jpg" width=500 height=300/>
#
# Pertama-tama, mari kita import terlebih dahulu library-library yang akan kita gunakan dalam proses data analysis:

# %%
# Import library-library yang akan digunakan
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Membaca Data
# Selanjutnya, kita dapat membaca data kita menggunakan fungsi `pd.read_csv()` yang terdapat di Pandas:

# %%
# Membaca data
url = "https://raw.githubusercontent.com/richardcsuwandi/ppsdcw2/main/bike_sales.csv"
data = pd.read_csv(url)
data
# Out:
#               Date  Day     Month  Year  ...  Unit_Price Profit  Cost Revenue
# 0       2013-11-26   26  November  2013  ...         120    590   360     950
# 1       2015-11-26   26  November  2015  ...         120    590   360     950
# 2       2014-03-23   23     March  2014  ...         120   1366  1035    2401
# 3       2016-03-23   23     March  2016  ...         120   1188   900    2088
# 4       2014-05-15   15       May  2014  ...         120    238   180     418
# ...            ...  ...       ...   ...  ...         ...    ...   ...     ...
# 113031  2016-04-12   12     April  2016  ...          64    112    72     184
# 113032  2014-04-02    2     April  2014  ...          64    655   528    1183
# 113033  2016-04-02    2     April  2016  ...          64    655   528    1183
# 113034  2014-03-04    4     March  2014  ...          64    684   576    1260
# 113035  2016-03-04    4     March  2016  ...          64    655   552    1207
#
# [113036 rows x 18 columns]

# %% [markdown]
# ### Melihat Data
# Berikut adalah beberapa fungsi dasar untuk melihat data di Pandas:
# - `head(n)` : Berfungsi untuk melihat data sebanyak n pada baris awal (jika tidak diisi, secara default n = 5)
# - `tail(n)`: Berfungsi untuk melihat data sebanyak n pada baris akhir (jika tidak diisi, secara default n = 5)
# - `shape` : Melihat jumlah baris dan kolom.
# - `info()` : Menampilkan nomor index beserta tipe datanya.
# - `describe()` : Menunjukkan rangkuman statistik seperti rata-rata, median, dll pada kolom.

# %%
# Menggunakan head
data.head(n=3)
# Out:
#          Date  Day     Month  Year  ...  Unit_Price Profit  Cost Revenue
# 0  2013-11-26   26  November  2013  ...         120    590   360     950
# 1  2015-11-26   26  November  2015  ...         120    590   360     950
# 2  2014-03-23   23     March  2014  ...         120   1366  1035    2401
#
# [3 rows x 18 columns]

# %%
# Menggunakan tail
data.tail(n=3)
# Out:
#               Date  Day  Month  Year  ...  Unit_Price Profit Cost Revenue
# 113033  2016-04-02    2  April  2016  ...          64    655  528    1183
# 113034  2014-03-04    4  March  2014  ...          64    684  576    1260
# 113035  2016-03-04    4  March  2016  ...          64    655  552    1207
#
# [3 rows x 18 columns]

# %%
# Menggunakan shape
data.shape
# Out:
# (113036, 18)

# %%
# Menggunakan info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
#  16  Cost              113036 non-null  int64
#  17  Revenue           113036 non-null  int64
# dtypes: int64(9), object(9)
# memory usage: 15.5+ MB

# %%
# Menggunakan describe
data.describe()
# Out:
#                  Day           Year  ...           Cost        Revenue
# count  113036.000000  113036.000000  ...  113036.000000  113036.000000
# mean       15.665753    2014.401739  ...     469.318695     754.370360
# std         8.781567       1.272510  ...     884.866118    1309.094674
# min         1.000000    2011.000000  ...       1.000000       2.000000
# 25%         8.000000    2013.000000  ...      28.000000      63.000000
# 50%        16.000000    2014.000000  ...     108.000000     223.000000
# 75%        23.000000    2016.000000  ...     432.000000     800.000000
# max        31.000000    2016.000000  ...   42978.000000   58074.000000
#
# [8 rows x 9 columns]

# %% [markdown]
# ### Memilih Data
# Terdapat dua metode untuk memilih baris dan kolom di Pandas, yaitu menggunakan `iloc` dan `loc`. Secara singkat, `iloc` memilih data berdasarkan indeks/posisi nya, sedangkan `loc` memilih data berdasarkan dengan labelnya.

# %% [markdown]
# #### 1. iloc
# Kita dapat memilih baris dan kolom dengan `iloc` menggunakan syntax seperti berikut:
#
# `data.iloc[indeks baris, indeks kolom]`

# %%
# Memilih baris dan kolom menggunakan iloc
data.iloc[0, 2]
# Out:
# 'November'

# %%
# Memilih baris menggunakan iloc
data.iloc[0]
# Out:
# Date                         2013-11-26
# Day                                  26
# Month                          November
# Year                               2013
# Customer_Age                         19
# Age_Group                   Youth (<25)
# Customer_Gender                       M
# Country                          Canada
# State                  British Columbia
# Product_Category            Accessories
# Sub_Category                 Bike Racks
# Product             Hitch Rack - 4-Bike
# Order_Quantity                        8
# Unit_Cost                            45
# Unit_Price                          120
# Profit                              590
# Cost                                360
# Revenue                             950
# Name: 0, dtype: object

# %%
# Memilih kolom menggunakan iloc
data.iloc[:, 2]
# Out:
# 0         November
# 1         November
# 2            March
# 3            March
# 4              May
#             ...
# 113031       April
# 113032       April
# 113033       April
# 113034       March
# 113035       March
# Name: Month, Length: 113036, dtype: object

# %%
# Memilih beberapa baris dan kolom menggunakan iloc
data.iloc[0:5, [4, 7, 11]]
# Out:
#    Customer_Age    Country              Product
# 0            19     Canada  Hitch Rack - 4-Bike
# 1            19     Canada  Hitch Rack - 4-Bike
# 2            49  Australia  Hitch Rack - 4-Bike
# 3            49  Australia  Hitch Rack - 4-Bike
# 4            47  Australia  Hitch Rack - 4-Bike

# %% [markdown]
# #### 2. loc
# Kita dapat memilih baris dan kolom dengan `loc` menggunakan syntax seperti berikut:
#
# `data.loc[indeks baris, nama kolom]`

# %%
# Memilih baris dan kolom menggunakan loc
data.loc[0, "Product"]
# Out:
# 'Hitch Rack - 4-Bike'

# %%
# Memilih kolom menggunakan loc
data.loc[:, "Product"]
# Out:
# 0         Hitch Rack - 4-Bike
# 1         Hitch Rack - 4-Bike
# 2         Hitch Rack - 4-Bike
# 3         Hitch Rack - 4-Bike
# 4         Hitch Rack - 4-Bike
#                  ...
# 113031        Classic Vest, S
# 113032        Classic Vest, M
# 113033        Classic Vest, M
# 113034        Classic Vest, L
# 113035        Classic Vest, L
# Name: Product, Length: 113036, dtype: object

# %%
# Memilih beberapa baris dan kolom menggunakan loc
data.loc[0:4, ["Customer_Age", "Country", "Product"]]
# Out:
#    Customer_Age    Country              Product
# 0            19     Canada  Hitch Rack - 4-Bike
# 1            19     Canada  Hitch Rack - 4-Bike
# 2            49  Australia  Hitch Rack - 4-Bike
# 3            49  Australia  Hitch Rack - 4-Bike
# 4            47  Australia  Hitch Rack - 4-Bike

# %% [markdown]
# Note:
#
# `iloc` menggunakan aturan indexing yang sama dengan Python dimana elemen pertama pada range diikutkan sedangkan elemen terakhir tidak diikutkan Sehingga untuk range `0:5`, `iloc` akan memilih  elemen 0,1,2,3,4.
#
# Sedangkan, `loc` mengikutsertakan elemen terakhir pada range sehingga untuk range `0:5` yang dipilih adalah elemen 0,1,2,3,4,5.

# %% [markdown]
# #### **Latihan**
# Gunakan `iloc` atau `loc` untuk memilih 100 baris pertama dengan kolom `Product`, `Unit_Price`, dan 'Order_Quantity`

# %%
# Jawaban:
# Menggunakan loc
data.loc[0:99, ["Product", "Unit_Price", "Order_Quantity"]]
# Out:
#                 Product  Unit_Price  Order_Quantity
# 0   Hitch Rack - 4-Bike         120               8
# 1   Hitch Rack - 4-Bike         120               8
# 2   Hitch Rack - 4-Bike         120              23
# 3   Hitch Rack - 4-Bike         120              20
# 4   Hitch Rack - 4-Bike         120               4
# ..                  ...         ...             ...
# 95  Hitch Rack - 4-Bike         120              29
# 96  Hitch Rack - 4-Bike         120               3
# 97  Hitch Rack - 4-Bike         120               1
# 98  Hitch Rack - 4-Bike         120               8
# 99  Hitch Rack - 4-Bike         120               9
#
# [100 rows x 3 columns]

# %%
# Jawaban:
# Menggunakan iloc
data.iloc[0:100, [11, 14, 12]]
# Out:
#                 Product  Unit_Price  Order_Quantity
# 0   Hitch Rack - 4-Bike         120               8
# 1   Hitch Rack - 4-Bike         120               8
# 2   Hitch Rack - 4-Bike         120              23
# 3   Hitch Rack - 4-Bike         120              20
# 4   Hitch Rack - 4-Bike         120               4
# ..                  ...         ...             ...
# 95  Hitch Rack - 4-Bike         120              29
# 96  Hitch Rack - 4-Bike         120               3
# 97  Hitch Rack - 4-Bike         120               1
# 98  Hitch Rack - 4-Bike         120               8
# 99  Hitch Rack - 4-Bike         120               9
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Memfilter Data
# Kita bisa memfilter atau menyeleksi data berdasarkan kondisi. Beberapa orang menyebutnya *Boolean Selection* atau *Boolean Indexing* karena kita menggunakan logika yang sama seperti ketika kita ingin membuat kondisi pada if else.

# %%
# Memfilter data berdasarkan jenis kelamin
kondisi = data["Customer_Gender"] == "F"
data[kondisi]
# Out:
#               Date  Day      Month  Year  ...  Unit_Price Profit Cost Revenue
# 4       2014-05-15   15        May  2014  ...         120    238  180     418
# 5       2016-05-15   15        May  2016  ...         120    297  225     522
# 6       2014-05-22   22        May  2014  ...         120    199  180     379
# 7       2016-05-22   22        May  2016  ...         120    100   90     190
# 10      2013-07-30   30       July  2013  ...         120    398  360     758
# ...            ...  ...        ...   ...  ...         ...    ...  ...     ...
# 113013  2015-09-16   16  September  2015  ...          64    778  720    1498
# 113014  2013-12-10   10   December  2013  ...          64    207  192     399
# 113015  2015-12-10   10   December  2015  ...          64    156  144     300
# 113034  2014-03-04    4      March  2014  ...          64    684  576    1260
# 113035  2016-03-04    4      March  2016  ...          64    655  552    1207
#
# [54724 rows x 18 columns]

# %%
# Memfilter data berdasarkan usia
kondisi = data["Customer_Age"] > 18
data[kondisi]
# Out:
#               Date  Day     Month  Year  ...  Unit_Price Profit  Cost Revenue
# 0       2013-11-26   26  November  2013  ...         120    590   360     950
# 1       2015-11-26   26  November  2015  ...         120    590   360     950
# 2       2014-03-23   23     March  2014  ...         120   1366  1035    2401
# 3       2016-03-23   23     March  2016  ...         120   1188   900    2088
# 4       2014-05-15   15       May  2014  ...         120    238   180     418
# ...            ...  ...       ...   ...  ...         ...    ...   ...     ...
# 113029  2015-12-28   28  December  2015  ...          64     75    48     123
# 113030  2014-04-12   12     April  2014  ...          64    225   144     369
# 113031  2016-04-12   12     April  2016  ...          64    112    72     184
# 113034  2014-03-04    4     March  2014  ...          64    684   576    1260
# 113035  2016-03-04    4     March  2016  ...          64    655   552    1207
#
# [109970 rows x 18 columns]

# %% [markdown]
# Untuk memfilter data dengan lebih dari satu kondisi, kita dapat menggunakan:
# - Simbol `&` untuk `dan`
# - Simbol `|` untuk `atau`

# %%
# Memfilter data berdasarkan jenis kelamin dan usia
kondisi_1 = data["Customer_Gender"] == "F"
kondisi_2 = data["Customer_Age"] > 18
kondisi = kondisi_1 & kondisi_2 
data[kondisi]
# Out:
#               Date  Day      Month  Year  ...  Unit_Price Profit Cost Revenue
# 4       2014-05-15   15        May  2014  ...         120    238  180     418
# 5       2016-05-15   15        May  2016  ...         120    297  225     522
# 6       2014-05-22   22        May  2014  ...         120    199  180     379
# 7       2016-05-22   22        May  2016  ...         120    100   90     190
# 10      2013-07-30   30       July  2013  ...         120    398  360     758
# ...            ...  ...        ...   ...  ...         ...    ...  ...     ...
# 113013  2015-09-16   16  September  2015  ...          64    778  720    1498
# 113014  2013-12-10   10   December  2013  ...          64    207  192     399
# 113015  2015-12-10   10   December  2015  ...          64    156  144     300
# 113034  2014-03-04    4      March  2014  ...          64    684  576    1260
# 113035  2016-03-04    4      March  2016  ...          64    655  552    1207
#
# [53474 rows x 18 columns]

# %% [markdown]
# Kita dapat menggunakan fungsi `isin` untuk memilih data yang nilainya terdapat dalam sebuah list.

# %%
# Menggunakan isin
kondisi = data["Product_Category"].isin(["Accessories", "Clothing"])
data[kondisi]
# Out:
#               Date  Day     Month  Year  ...  Unit_Price Profit  Cost Revenue
# 0       2013-11-26   26  November  2013  ...         120    590   360     950
# 1       2015-11-26   26  November  2015  ...         120    590   360     950
# 2       2014-03-23   23     March  2014  ...         120   1366  1035    2401
# 3       2016-03-23   23     March  2016  ...         120   1188   900    2088
# 4       2014-05-15   15       May  2014  ...         120    238   180     418
# ...            ...  ...       ...   ...  ...         ...    ...   ...     ...
# 113031  2016-04-12   12     April  2016  ...          64    112    72     184
# 113032  2014-04-02    2     April  2014  ...          64    655   528    1183
# 113033  2016-04-02    2     April  2016  ...          64    655   528    1183
# 113034  2014-03-04    4     March  2014  ...          64    684   576    1260
# 113035  2016-03-04    4     March  2016  ...          64    655   552    1207
#
# [87054 rows x 18 columns]

# %% [markdown]
# #### **Latihan**
# Dapatkan seluruh data penjualan di negara `Australia` untuk pelanggan dalam kelompok umur `Adults (35-64)`

# %%
# Jawaban:
data[(data['Country'] == "Australia") & (data["Age_Group"] == "Adults (35-64)")]
# Out:
#               Date  Day    Month  Year  ...  Unit_Price Profit  Cost Revenue
# 2       2014-03-23   23    March  2014  ...         120   1366  1035    2401
# 3       2016-03-23   23    March  2016  ...         120   1188   900    2088
# 4       2014-05-15   15      May  2014  ...         120    238   180     418
# 5       2016-05-15   15      May  2016  ...         120    297   225     522
# 6       2014-05-22   22      May  2014  ...         120    199   180     379
# ...            ...  ...      ...   ...  ...         ...    ...   ...     ...
# 112989  2015-10-25   25  October  2015  ...          64    536   432     968
# 112996  2014-03-25   25    March  2014  ...          64    285   216     501
# 112997  2016-03-25   25    March  2016  ...          64    317   240     557
# 112998  2014-04-06    6    April  2014  ...          64    792   600    1392
# 112999  2016-04-06    6    April  2016  ...          64    697   528    1225
#
# [10394 rows x 18 columns]

# %% [markdown]
# ### Sorting dan Grouping Data
# Kita dapat melakukan sorting data dengan menggunakan fungsi `sort_values()` pada Pandas. Secara default, data akan diurutkan dari nilai yang rendah ke tinggi (secara ascending). Akan tetapi, kita juga dapat mengurutkan data dari tinggi ke rendah (descending) dengan cara menambahkan argumen `ascending = False`

# %%
# Menggunakan sort_values
data.sort_values(by="Order_Quantity", ascending=False)
# Out:
#              Date  Day      Month  Year  ...  Unit_Price Profit  Cost Revenue
# 26099  2015-08-06    6     August  2015  ...          22    441   256     697
# 29583  2015-11-15   15   November  2015  ...          24    319   288     607
# 16386  2015-07-26   26       July  2015  ...           5     75    64     139
# 48231  2015-12-28   28   December  2015  ...          54      4  1344    1348
# 81899  2015-09-14   14  September  2015  ...          25    400   288     688
# ...           ...  ...        ...   ...  ...         ...    ...   ...     ...
# 55256  2014-01-08    8    January  2014  ...        2295    951  1252    2203
# 55257  2016-01-08    8    January  2016  ...        2295    951  1252    2203
# 55258  2014-02-09    9   February  2014  ...        2295    951  1252    2203
# 55259  2016-02-09    9   February  2016  ...        2295    951  1252    2203
# 56518  2013-06-12   12       June  2013  ...         540    234   295     529
#
# [113036 rows x 18 columns]

# %%
# Menggunakan sort_values dengan beberapa kolom
data.sort_values(by=["Order_Quantity", "Unit_Price"], ascending=False)
# Out:
#               Date  Day      Month  Year  ...  Unit_Price Profit Cost Revenue
# 72333   2015-08-06    6     August  2015  ...          70   1094  832    1926
# 72655   2016-05-02    2        May  2016  ...          70   1094  832    1926
# 73325   2016-06-15   15       June  2016  ...          70   1005  832    1837
# 112143  2016-02-16   16   February  2016  ...          64   1014  768    1782
# 42385   2015-09-09    9  September  2015  ...          55    859  672    1531
# ...            ...  ...        ...   ...  ...         ...    ...  ...     ...
# 107705  2015-12-16   16   December  2015  ...           2      1    1       2
# 107947  2015-10-21   21    October  2015  ...           2      1    1       2
# 107952  2015-10-22   22    October  2015  ...           2      1    1       2
# 108165  2015-12-14   14   December  2015  ...           2      1    1       2
# 108356  2015-10-10   10    October  2015  ...           2      1    1       2
#
# [113036 rows x 18 columns]

# %% [markdown]
# Di Pandas, kita juga dapat melakukan pengelompokan data berdasarkan kolom tertentu menggunakan fungsi `groupby()`

# %%
# Grouping berdasarkan product
data_by_product = data.groupby("Product")
data_by_product

# %% [markdown]
# Setelah melakukan grouping, kita akan mendapatkan `DataFrameGroupBy object` yang dapat kita gunakan untuk melakukan berbagai analisis dan perhitungan statistik

# %%
# Menghitung jumlah dengan count
data_by_product.count()
# Out:
#                              Date    Day  Month  ...  Profit   Cost  Revenue
# Product                                          ...
# AWC Logo Cap                 4358   4358   4358  ...    4358   4358     4358
# All-Purpose Bike Stand        452    452    452  ...     452    452      452
# Bike Wash - Dissolver        1804   1804   1804  ...    1804   1804     1804
# Classic Vest, L               318    318    318  ...     318    318      318
# Classic Vest, M               320    320    320  ...     320    320      320
# ...                           ...    ...    ...  ...     ...    ...      ...
# Touring-3000 Yellow, 62        72     72     72  ...      72     72       72
# Water Bottle - 30 oz.       10794  10794  10794  ...   10794  10794    10794
# Women's Mountain Shorts, L    516    516    516  ...     516    516      516
# Women's Mountain Shorts, M    662    662    662  ...     662    662      662
# Women's Mountain Shorts, S    620    620    620  ...     620    620      620
#
# [130 rows x 17 columns]

# %%
# Menghitung rata-rata pada masing-masing kategori
data_by_product["Revenue"].mean()
# Out:
# Product
# AWC Logo Cap                   126.025700
# All-Purpose Bike Stand         758.106195
# Bike Wash - Dissolver          110.169069
# Classic Vest, L                845.732704
# Classic Vest, M                871.137500
#                                  ...
# Touring-3000 Yellow, 62        786.583333
# Water Bottle - 30 oz.           69.113860
# Women's Mountain Shorts, L     938.331395
# Women's Mountain Shorts, M    1001.744713
# Women's Mountain Shorts, S     961.753226
# Name: Revenue, Length: 130, dtype: float64

# %%
# Menghitung nilai maksimum/minimum
data_by_product["Order_Quantity"].max()
# Out:
# Product
# AWC Logo Cap                  32
# All-Purpose Bike Stand        12
# Bike Wash - Dissolver         32
# Classic Vest, L               31
# Classic Vest, M               31
#                               ..
# Touring-3000 Yellow, 62        3
# Water Bottle - 30 oz.         32
# Women's Mountain Shorts, L    31
# Women's Mountain Shorts, M    32
# Women's Mountain Shorts, S    32
# Name: Order_Quantity, Length: 130, dtype: int64

# %% [markdown]
# Kita juga dapat melakukan beberapa perhitungan sekaligus menggunakan fungsi `agg()`

# %%
# Menggunakan agg
data_by_product["Order_Quantity"].agg(["min", "max", "mean"])
# Out:
#                             min  max       mean
# Product
# AWC Logo Cap                  1   32  15.446535
# All-Purpose Bike Stand        1   12   5.309735
# Bike Wash - Dissolver         1   32  15.287694
# Classic Vest, L               1   31  14.625786
# Classic Vest, M               1   31  15.237500
# ...                         ...  ...        ...
# Touring-3000 Yellow, 62       1    3   1.152778
# Water Bottle - 30 oz.         1   32  15.201593
# Women's Mountain Shorts, L    1   31  14.767442
# Women's Mountain Shorts, M    1   32  15.584592
# Women's Mountain Shorts, S    1   32  14.956452
#
# [130 rows x 3 columns]

# %% [markdown]
# #### **Latihan**
# Berapakah nilai minimum, maksimum, dan rata-rata `Order_Quantity` untuk setiap kategori produk?

# %%
# Jawaban:
data_by_prod_cat = data.groupby("Product_Category")
data_by_prod_cat["Order_Quantity"].agg(["min", "max", "mean"])
# Out:
#                   min  max       mean
# Product_Category
# Accessories         1   32  15.033685
# Bikes               1    4   1.401393
# Clothing            1   32  15.043286

# %% [markdown]
# ### Visualisasi Data
# Kita juga dapat melakukan data visualisasi di Pandas yang didukung oleh library [Matplotlib](https://matplotlib.org).
#
# Dengan fungsi `plot`, kita dapat menghasilkan berbagai jenis visualisasi data melalui argumen `kind` sebagai berikut:
#
# - "bar" untuk bar chart (vertikal)
# - "barh" untuk bar chart (horizontal)
# - "pie" untuk pie chart
# - "hist" untuk histogram
# - "box" untuk box plot
#
# List lebih lengkap dapat dilihat di link [ini](https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html)

# %%
# Membuat bar chart (vertikal)
data_by_prod_cat["Product"].count().plot(kind="bar")

# %% [markdown]
# Salah satu fungsi lain yang berguna untuk plotting adalah `value_counts`. Dengan fungsi ini, kita dapat dengan mudah memperoleh jumlah observasi berdasarkan kategori/kolom tertentu

# %%
# Menggunakan value_counts
data["Product_Category"].value_counts().plot(kind="bar")

# %%
# Menambahkan title, xlabel, dan ylabel
data["Product_Category"].value_counts().plot(kind="bar",
                                             title="Jumlah Produk Berdasarkan Kategori Produk",
                                             xlabel="Kategori Produk",
                                             ylabel="Jumlah")

# %%
# Membuat histogram
data["Customer_Age"].plot(kind="hist")

# %%
# Membuat box plot
data["Customer_Age"].plot(kind="box", vert=False)

# %% [markdown]
# #### **Latihan**
# Buatlah sebuah pie chart untuk menunjukkan pembagian kategori `Age_Group` pada data penjualan. Tambahkan judul yang sesuai pada pie chart yang dihasilkan.

# %%
# Jawaban:
data["Age_Group"].value_counts().plot(kind="pie",
                                      title="Pembagian Kelompok Umur Pelanggan")

# %% [markdown]
# ## Thanks for joining!
# Feel free to connect with me:
#
# [<img align="left" alt="richardcsuwandi.github.io" width="30px" src="https://raw.githubusercontent.com/iconic/open-iconic/master/svg/globe.svg"/>][Website]
#
# [<img align="left" alt="linkedin.com/richardcsuwandi" width="30px" src="https://cdn.jsdelivr.net/npm/simple-icons@v3/icons/linkedin.svg" />][LinkedIn]
#
# [<img align="left" alt="twitter.com/richardcsuwandi" width="30px" src="https://cdn.jsdelivr.net/npm/simple-icons@v3/icons/twitter.svg" />][Twitter]
#
# [<img align="left" alt="https://www.instagram.com/richardcsuwandi" width="30px" src="http://simpleicons.org/icons/instagram.svg" />][Instagram]
#
# [<img align="left" alt="https://www.github.com/richardcsuwandi" width="30px" src="http://simpleicons.org/icons/github.svg" />][GitHub]
#
# [Website]: https://richardcsuwandi.github.io
# [Twitter]: https://twitter.com/richardcsuwandi
# [LinkedIn]: https://linkedin.com/in/richardcsuwandi
# [Instagram]: https://instagram.com/richardcsuwandi
# [GitHub]: https://github.com/richardcsuwandi

# %% [markdown]
# #### References:
# - https://pandas.pydata.org/pandas-docs/stable/getting_started/index.html
# - https://www.kaggle.com/learn/pandas
